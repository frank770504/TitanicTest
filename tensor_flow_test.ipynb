# %%
import pandas as pd
import numpy as np
import os

os.chdir('/notebooks/pycharm/TitanicTest/')

from extract_titanic import get_training_data

# %%
x_train, y_train, panda_train = get_training_data('/notebooks/pycharm/TitanicTest/train.csv')
panda_train[:5]
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Gender
# 0         0       3  22.0      1      0   7.2500         2       1
# 1         1       1  38.0      1      0  71.2833         0       0
# 2         1       3  26.0      0      0   7.9250         2       0
# 3         1       1  35.0      1      0  53.1000         2       0
# 4         0       3  35.0      0      0   8.0500         2       1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
panda_train.Age
panda_train['Age_stdz'] = (panda_train.Age - panda_train.Age.mean()) / panda_train.Age.std()
vison = 30
panda_train.Age[:vison].plot()
plt.figure()
panda_train.Age_stdz[:vison].plot()
